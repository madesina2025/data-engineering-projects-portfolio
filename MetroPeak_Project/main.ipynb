# %%
import pandas as pd
import requests
import json
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# /Users/mkadesina/Documents/Projects-DataEngineering/MetroPeak_Project/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# True

# %%
my_key = os.getenv('api_key')
#print(my_key)

# %%
url = "https://api.rentcast.io/v1/properties/random?limit=500"

headers = {"accept": "application/json",
           'X-Api-Key':my_key}

response = requests.get(url, headers=headers)
data = response.json()

# %%
data
# Out:
# [{'id': '16-Lancea-Pl,-Tustin,-CA-92782',
#   'formattedAddress': '16 Lancea Pl, Tustin, CA 92782',
#   'addressLine1': '16 Lancea Pl',
#   'addressLine2': None,
#   'city': 'Tustin',
#   'state': 'CA',
#   'stateFips': '06',
#   'zipCode': '92782',
#   'county': 'Orange',
#   'countyFips': '059',
#   'latitude': 33.703484,
#   'longitude': -117.815665,
#   'propertyType': 'Single Family',
#   'bedrooms': 4,
#   'bathrooms': 3,
#   'squareFootage': 2912,
#   'lotSize': 3833,
#   'yearBuilt': 2015,
#   'assessorID': '430-441-06',
#   'legalDescription': 'N TR 17507 BLK LOT 305',
#   'lastSaleDate': '2015-11-30T00:00:00.000Z',
#   'lastSalePrice': 960000,
#   'features': {'garage': True, 'garageSpaces': 2, 'garageType': 'Garage'},
#   'taxAssessments': {'2020': {'year': 2020,
#     'value': 1039025,
#     'land': 455485,
#     'improvements': 583540},
#    '2023': {'year': 2023,
#     'value': 1092199,
#     'land': 478796,
#     'improvements': 613403}},
# ...

# %%
df = pd.json_normalize(data)
df
# Out:
#                                                    id  \
# 0                      16-Lancea-Pl,-Tustin,-CA-92782
# 1                505-S-23rd-St,-Terre-Haute,-IN-47803
# 2                  208-Alice-St,-Charlevoix,-MI-49720
# 3                  22-Pointer-Trl,-Picayune,-MS-39466
# 4                 1001-S-13th-St,-Chickasha,-OK-73018
# ..                                                ...
# 495  3500-Windcliff-Dr-SE,---1116,-Marietta,-GA-30067
# 496                       Moira-Rd,-Edwards,-MO-65326
# 497              1401-Norman-Ave,-Las-Vegas,-NV-89104
# 498               851-Bacon-Hall-Rd,-Sparks,-MD-21152
# 499              6548-Via,-Rosa,-Boca-Raton,-FL-33433
#
#                                      formattedAddress          addressLine1  \
# 0                      16 Lancea Pl, Tustin, CA 92782          16 Lancea Pl
# 1                505 S 23rd St, Terre Haute, IN 47803         505 S 23rd St
# 2                  208 Alice St, Charlevoix, MI 49720          208 Alice St
# ...

# %%
df.shape
# Out:
# (500, 903)

# %%
df.dtypes
# Out:
# id                           object
# formattedAddress             object
# addressLine1                 object
# addressLine2                 object
# city                         object
#                              ...
# history.2019-03-14.date      object
# history.2019-03-14.price    float64
# history.2022-08-03.event     object
# history.2022-08-03.date      object
# history.2022-08-03.price    float64
# Length: 951, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    id  \
# 0                      16-Lancea-Pl,-Tustin,-CA-92782
# 1                505-S-23rd-St,-Terre-Haute,-IN-47803
# 2                  208-Alice-St,-Charlevoix,-MI-49720
# 3                  22-Pointer-Trl,-Picayune,-MS-39466
# 4                 1001-S-13th-St,-Chickasha,-OK-73018
# ..                                                ...
# 495  3500-Windcliff-Dr-SE,---1116,-Marietta,-GA-30067
# 496                       Moira-Rd,-Edwards,-MO-65326
# 497              1401-Norman-Ave,-Las-Vegas,-NV-89104
# 498               851-Bacon-Hall-Rd,-Sparks,-MD-21152
# 499              6548-Via,-Rosa,-Boca-Raton,-FL-33433
#
#                                      formattedAddress          addressLine1  \
# 0                      16 Lancea Pl, Tustin, CA 92782          16 Lancea Pl
# 1                505 S 23rd St, Terre Haute, IN 47803         505 S 23rd St
# ...

# %%
df.keys
# Out:
# <bound method NDFrame.keys of                                                    id  \
# 0                      16-Lancea-Pl,-Tustin,-CA-92782
# 1                505-S-23rd-St,-Terre-Haute,-IN-47803
# 2                  208-Alice-St,-Charlevoix,-MI-49720
# 3                  22-Pointer-Trl,-Picayune,-MS-39466
# 4                 1001-S-13th-St,-Chickasha,-OK-73018
# ..                                                ...
# 495  3500-Windcliff-Dr-SE,---1116,-Marietta,-GA-30067
# 496                       Moira-Rd,-Edwards,-MO-65326
# 497              1401-Norman-Ave,-Las-Vegas,-NV-89104
# 498               851-Bacon-Hall-Rd,-Sparks,-MD-21152
# 499              6548-Via,-Rosa,-Boca-Raton,-FL-33433
#
#                                      formattedAddress          addressLine1  \
# 0                      16 Lancea Pl, Tustin, CA 92782          16 Lancea Pl
# 1                505 S 23rd St, Terre Haute, IN 47803         505 S 23rd St
# ...

# %%
df.columns[:70]
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'stateFips', 'zipCode', 'county', 'countyFips', 'latitude',
#        'longitude', 'propertyType', 'bedrooms', 'bathrooms', 'squareFootage',
#        'lotSize', 'yearBuilt', 'assessorID', 'legalDescription',
#        'lastSaleDate', 'lastSalePrice', 'ownerOccupied', 'features.garage',
#        'features.garageSpaces', 'features.garageType',
#        'taxAssessments.2020.year', 'taxAssessments.2020.value',
#        'taxAssessments.2020.land', 'taxAssessments.2020.improvements',
#        'taxAssessments.2023.year', 'taxAssessments.2023.value',
#        'taxAssessments.2023.land', 'taxAssessments.2023.improvements',
#        'propertyTaxes.2020.year', 'propertyTaxes.2020.total',
#        'propertyTaxes.2023.year', 'propertyTaxes.2023.total',
#        'history.2015-11-30.event', 'history.2015-11-30.date',
#        'history.2015-11-30.price', 'owner.names', 'owner.type',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Columns: 951 entries, id to history.2022-08-03.price
# dtypes: float64(323), object(628)
# memory usage: 3.6+ MB

# %%
df.shape
# Out:
# (500, 951)

# %%
import os
import urllib.parse as up            # <-- this fixes the NameError
from dotenv import load_dotenv
from dotenv import load_dotenv, find_dotenv
import sqlalchemy
from sqlalchemy import create_engine, text
# Load .env
load_dotenv()
import urllib.parse as up
import os

# Load .env from project root
load_dotenv(find_dotenv())   # no prints, no secrets leaked
# Out:
# True

# %%
username=os.getenv('username')
password=os.getenv('password')

# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os, urllib.parse as up

load_dotenv()
username = os.getenv('username')
password = os.getenv('password')
host     = os.getenv('host', '127.0.0.1')
port     = os.getenv('port', '5433')
database = os.getenv('database', 'metropeak_staging')  # prefer lowercase
print("user:", bool(username), "host:", host, "port:", port, "db:", database)    
engine = create_engine(
    f"postgresql+psycopg2://{username}:{up.quote_plus(password)}@{host}:{port}/{database}"
)
print(engine.url)
# Out:
# user: True host: 127.0.0.1 port: 5432 db: MetroPeak_staging
# postgresql+psycopg2://postgres:***@127.0.0.1:5432/MetroPeak_staging

# %%
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import os, urllib.parse as up

load_dotenv()

user = os.getenv("username")
pwd  = up.quote_plus(os.getenv("password"))
host = os.getenv("host", "127.0.0.1")
port = os.getenv("port", "5433")
db   = os.getenv("database")  # your target

# connect to maintenance DB to inspect
admin = create_engine(f"postgresql+psycopg2://{user}:{pwd}@{host}:{port}/postgres")

with admin.connect() as c:
    names = [r[0] for r in c.execute(text("SELECT datname FROM pg_database ORDER BY datname;"))]
print("Databases:", names)
print("Target in .env:", db)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Documents/Projects-DataEngineering/MetroPeak_Project/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/Documents/Projects-DataEngineering/MetroPeak_Project/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)
#    3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# ...

# %%
# quick connection test (no secrets printed)
from sqlalchemy import text

with engine.connect() as conn:
    print("DB ping:", conn.execute(text("SELECT 1")).scalar())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Documents/Projects-DataEngineering/MetroPeak_Project/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/Documents/Projects-DataEngineering/MetroPeak_Project/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)
#    3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# ...

# %%
# engine= create_engine(f'postresql://postgres:(password)@localhost:5433/MetroPeak_staging')
# df.to_sql('df',engine,if_exists='replace',index=False)

# %%
engine = create_engine(
    'postgresql://postgres@localhost:5433/MetroPeak_staging')
df.to_sql('df', engine, if_exists='replace', index=False)

# %%
# load .env from the project root
load_dotenv(find_dotenv())

user = os.getenv("PGUSER")                 # e.g., postgres
pwd  = os.getenv("PGPASSWORD")             # e.g., yourStrong$Pass
host = os.getenv("PGHOST", "127.0.0.1")    # use IPv4
port = os.getenv("PGPORT", "5433")
db   = os.getenv("PGDATABASE", "MetroPeak_staging")  # prefer lowercase

# sanity: fail fast if missing
assert user and pwd and db, "Missing PGUSER/PGPASSWORD/PGDATABASE in .env"

# ✅ correct URL (note the slash between port and db!)
engine = create_engine(
    f"postgresql+psycopg2://{user}:{up.quote_plus(pwd)}@{host}:{port}/{db}"
)

# quick ping
with engine.connect() as c:
    c.execute(text("SELECT 1"))
